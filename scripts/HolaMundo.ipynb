# %%
from pyspark.sql import SparkSession

# 1. Iniciamos la sesión de Spark configurada para Cassandra
spark = SparkSession.builder \
    .appName("Validacion_Conectividad_Fase1.4") \
    .config("spark.cassandra.connection.host", "cassandra") \
    .getOrCreate()

print("--> ¡Hola Mundo!")
# Out:
# --> ¡Hola Mundo!
